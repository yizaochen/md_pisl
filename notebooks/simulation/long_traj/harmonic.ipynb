# %%
using FEM, Potential, PyPlot, Printf, JLD

# %% [markdown]
# ### Part 1: Get collocation points and integration kernel for whole domain

# %%
Nh = 64    # The number of Spectral element
Np = 4     # The order of polynomial which used to interpolate and integration

# Define Physical Domain
xratio = 0.5 # unit: dimensionless
xavg = 0   # unit: dimensionless

x, w, Ldx, L = getLagrange(Np, xratio/Nh)
e_norm = x[end] - x[1]
interpo_xs = x .+ x[end]

N, xref, w0, Ldx, w = get_fem_xref_weights_basis(Nh, Np, xratio, xavg);

# %% [markdown]
# ### Part 2: Set $V(x)$ and $p_{\rm eq}(x)$

# %%
kref = 247.15 
Vref = harmonic_well_k_mean(xref, k, xavg)
rho_eq = get_rhoeq(Vref, w0)
p_eq = rho_eq .* rho_eq;

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(4,4))

ax.plot(xref, peq, linewidth=2)
ax.set_xlabel("\$x\$", fontsize=12)
ax.set_ylabel("\$p_{\\rm eq}(x)\$", fontsize=12)
ax.set_xticks(-0.5:0.25:0.5)

plt.tight_layout()
plt.show()
# Out:
# Figure(PyObject <Figure size 400x400 with 1 Axes>)

# %% [markdown]
# #### Trajectory entropy

# %%
sum(w0 .* p_eq .* log.(p_eq))
# Out:
# 1.6826327690916143

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(4,4))

ax.plot(xref, Vref, linewidth=2)
ax.set_xlabel("\$x\$", fontsize=12)
ax.set_ylabel("\$V(x)\$", fontsize=12)
ax.set_xticks(-0.5:0.25:0.5)
ax.set_ylim(0, 10)

plt.tight_layout()
#plt.savefig("/home/yizaochen/Desktop/drawzone_temp/harmonic_potential.svg")
plt.show()
# Out:
# Figure(PyObject <Figure size 400x400 with 1 Axes>)

# %% [markdown]
# ### Part 3: Langenvin dynamics simulations

# %%
# physical parameters
save_freq = 1e-3 # unit: s, Save trajectory per 10e-3 s
total_times = 10 # unit: s, totol simulate 10 s
dt = 1e-5 # unit: s  # Integration Times 1ps
D = 1; # Diffusion coefficient, unit: s-1
tau = Int(round(total_times / save_freq, digits=0))  # Number of photons
n_interval = Int(round(save_freq / dt, digits=0));

time_info = @sprintf "Save trajectory per %d timesteps. There will be %d data points." n_interval tau
println(time_info)
# Out:
# Save trajectory per 100 timesteps. There will be 10000 data points.

# %%
# Initialize Variables
y_record = zeros(tau+1, 1)  # In HMM, observing variables Y(t)
t_record = zeros(tau+1, 1)

ypos = 0. # Initial Position, from mean position
t = 0

# Simulation Start
for tau_id = 1:tau
    y_record[tau_id] = ypos
    t_record[tau_id] = t
    for i = 1:n_interval
        F = force_harmonic_well_k_mean(ypos, kref, xavg)
        ypos = ypos + D*dt*F + (dt*2*D)^(1/2) * randn()
        t += dt   
    end
end
y_record[tau+1] = ypos
t_record[tau+1] = t;

# %% [markdown]
# ### Part 4: Save trajectory or Read trajectory

# %%
# Save simulated trajectory to jld file
f_out = "/home/yizaochen/codes/julia/md_pisl/trajectory/harmonic_well_0.jld"
save(f_out, "y_record", y_record, "t_record", t_record, "xref", xref, "rho_eq", rho_eq, "D", D, "k_ref", k_ref)

# %%
# Read simulated trajectory from jld file
f_in = "/home/yizaochen/codes/julia/md_pisl/trajectory/harmonic_dimensionless.jld"
y_record = load(f_in, "y_record")
t_record = load(f_in, "t_record")
xref = load(f_in, "xref")
rho_eq = load(f_in, "rho_eq")
k_ref = load(f_in, "k_ref")
D = load(f_in, "D");

# %% [markdown]
# ### Part 5: Plot

# %%
lbfz = 14
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12,4))

ax.plot(t_record, y_record)
ax.set_ylabel("x", fontsize=lbfz)
ax.set_xlabel("t", fontsize=lbfz)
ax.set_title(@sprintf "\$ D=%.1f~~\\Delta t=%.1e\$" D save_freq)
ax.set_ylim(-0.5, 0.5)

plt.tight_layout()
#plt.savefig("/home/yizaochen/Desktop/drawzone_temp/harmonic_traj.svg")
plt.show()
# Out:
# Figure(PyObject <Figure size 1200x400 with 1 Axes>)
