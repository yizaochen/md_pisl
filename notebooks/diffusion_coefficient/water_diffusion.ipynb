# %%
kbT = 4.11e-21
factor1 = 6 * pi
eta = 9e-4
a = 0.0484538e-10
D = kbT / (factor1 * eta *  a) # m^2 / s
# Out:
# 5.000003945015586e-8

# %%
D * 1e20 / 1e12 # angstrom^2 / ps
# Out:
# 5.000003945015586

# %%
kbT / (factor1 * eta * 1e-10) * (1e20 / 1e12)
# Out:
# 0.2422691911509962

# %%
0.2422691911509962 / 5
# Out:
# 0.04845383823019924
